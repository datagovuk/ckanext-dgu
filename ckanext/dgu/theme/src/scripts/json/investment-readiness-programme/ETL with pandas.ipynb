# %%
# Requirements need to be installed globally.
import ckanclient
import pandas
import requests
import numpy
# -- Pandas options
pandas.set_option('max_columns',99)
# -- Get some data
# !ls data
# Out:
# Bethnal Green Ventures (3.2.2014).xlsx   Social Incubator North (3.2.2014).xls
# Hub Launchpad (3.2.2014).xlsx            Wayra UnLtd (3.2.2014).xlsx
# ICRF Grants 31.01.14.xls                 ~$Bethnal Green Ventures (3.2.2014).xlsx

# %%
## LOAD INCUBATOR SUMMARIES
##
sheet0_headers = [
           'incubator', 'cash', 'date', 'cohort_id', 'cohort_name', 'cohort_start',
           'cohort_end', 'geo', 'num_interested', '_ignore1', '_ignore2',  'num_applications', 'source_applications',
           'source_applications2',
           'question1', 'question2', 'age_lead_applicants', 'age_winning_founders',
           'percent_male', 'percent_female', 'num_employees', 'percent_teams_one_female',
           'percent_teams_half_female',
           'num_beneficiaries', 'num_beneficiaries_increase_6months', 'num_countries',
           'num_investor_opportunities', 'total_new_investment', 'num_teams_on_icrf',
           'num_teams_on_other', 'num_teams_public_service_contracts', 'num_investors_engaged',
           'withdrawls'
]
def load_sheet0(filename):
    tmp = pandas.read_excel(filename,0,skip_footer=8,names=sheet0_headers)
    tmp = tmp[ tmp['incubator'].notnull() ]
    tmp = tmp.drop(['_ignore1','_ignore2'],axis=1)
    return tmp
# -- 
summary_bethnal = load_sheet0('data/Bethnal Green Ventures (3.2.2014).xlsx')
summary_hub     = load_sheet0('data/Hub Launchpad (3.2.2014).xlsx')
summary_north   = load_sheet0('data/Social Incubator North (3.2.2014).xls')
summary_wayra   = load_sheet0('data/Wayra UnLtd (3.2.2014).xlsx')
summarya = pandas.concat([ summary_bethnal, summary_hub, summary_north, summary_wayra ], ignore_index=True)
## -- This doesn't tell us a lot...
summary
# Out:
#                 incubator     cash        date  cohort_id  \
# 0  Bethnal Green Ventures   900000  13.02.2014          1
# 1           Hub Launchpad  1489500  15.03.2013          1
# 2  Social Incubator North  1489500  15.03.2013          1
# 3             Wayra UnLtd  1219006  13.02.2013          1
#
#                 cohort_name cohort_start  cohort_end geo  num_interested  \
# 0               Summer 2013   01.07.2013  27.09.2013  UK             NaN
# 1  Public Service Launchpad   25.01.2014  02.05.2014  UK             233
# 2                       NaN   05.08.2013  28.02.2014  UK             173
# 3                       NaN   01.09.2013  09.05.2014  UK             233
#
#    num_applications source_applications source_applications2  \
# 0                90   Existing networks         Social Media
# 1                92             Website             Partners
# 2               104             Website             Partners
# 3                92   Existing networks         Social Media
#
#           question1                         question2  age_lead_applicants  \
# 0  Team composition  Intellectual property protection                  NaN
# 1   Time commitment              Eligibility criteria                   40
# 2   Time commitment              Eligibility criteria                  NaN
# 3               NaN                               NaN                   33
#
#    age_winning_founders  percent_male  percent_female  num_employees  \
# 0                  33.5         60.00            0.40             27
# 1                   NaN           NaN             NaN            NaN
# 2                   NaN          0.60            0.40            NaN
# 3                  33.0          0.71            0.29             15
#
#    percent_teams_one_female  percent_teams_half_female  num_beneficiaries  \
# 0                       0.6                        0.3              50000
# 1                       NaN                        NaN                NaN
# 2                       NaN                        NaN                NaN
# 3                       0.8                        0.7                362
#
#    num_beneficiaries_increase_6months  num_countries  \
# 0                               36000              1
# 1                                 NaN            NaN
# 2                                   1              1
# 3                                 NaN             39
#
#    num_investor_opportunities  total_new_investment  num_teams_on_icrf  \
# 0                           2                248910                  0
# 1                         NaN                   NaN                NaN
# 2                           2                   NaN                NaN
# 3                         NaN                   NaN                NaN
#
#    num_teams_on_other  num_teams_public_service_contracts  \
# 0                   5                                   0
# 1                 NaN                                 NaN
# 2                 NaN                                   1
# 3                 NaN                                 NaN
#
#    num_investors_engaged  withdrawls
# 0                     30           0
# 1                    NaN         NaN
# 2                    NaN           5
# 3                    NaN           0
#
# [4 rows x 31 columns]

# %%
## IMPORT SUMMARY OF VENTURES
sheet1_headers = ['venture', 'target', 'target2', 'sector', 
 'sector2', 'invested_type', 'invested']
# Pad out the list of columns
actual_colz = 31
fake_colz = ['_drop%d'%i for i in range(actual_colz-len(sheet1_headers)) ]
# --
def load_sheet1(filename):
    tmp = pandas.read_excel(filename, 1, names=sheet1_headers+fake_colz)
    tmp = tmp.drop(fake_colz,axis=1)
    return tmp
ventures_bethnal = load_sheet1('data/Bethnal Green Ventures (3.2.2014).xlsx')
ventures_hub     = load_sheet1('data/Hub Launchpad (3.2.2014).xlsx')
ventures_north   = load_sheet1('data/Social Incubator North (3.2.2014).xls')
ventures_wayra   = load_sheet1('data/Wayra UnLtd (3.2.2014).xlsx')
ventures_bethnal['incubator'] = 'bethnal'
ventures_hub['incubator']     = 'hub'
ventures_north['incubator']   = 'north'
ventures_wayra['incubator']   = 'wayra'
ventures = pandas.concat([ventures_bethnal,ventures_hub,ventures_north,ventures_wayra],ignore_index=True)
ventures.tail()
# Out:
#                venture                 target       target2  \
# 60  MySupportAssistant         Adults in need   Communities
# 61          Provenance           Young people   Communities
# 62      Skin Analytics           Young people  Older people
# 63       StudentFunder         Adults in need  Young people
# 64        The DoNation  Children and families  Young people
#
#                                      sector  \
# 60       Employment, training and education
# 61       Employment, training and education
# 62                          Physical health
# 63       Employment, training and education
# 64  Conservation of the natural environment
#
#                                     sector2 invested_type  invested incubator
# 60              Mental health and wellbeing           NaN       NaN     wayra
# 61  Conservation of the natural environment           NaN       NaN     wayra
# 62                                      NaN           NaN       NaN     wayra
# 63                                      NaN           NaN       NaN     wayra
# 64                          Physical health           NaN       NaN     wayra
#
# [5 rows x 8 columns]

# %%
ventures.invested_type.value_counts()
# Out:
# Loan       45
# Equity     10
# dtype: int64

# %%
print ventures.target.value_counts()
print '---'
print ventures.target2.value_counts()
# Out:
# Communities                         25
# Young people                        16
# Children and families                7
# Other                                6
# People with disabilities             4
# Adults in need                       3
# People with high risk behaviours     2
# Older people                         2
# dtype: int64
# ---
# Young people                        6
# People with high risk behaviours    5
# Communities                         5
# Adults in need                      4
# Other                               3
# Older people                        1
# Children and families               1
# dtype: int64

# %%
print ventures.sector.value_counts()
print '---'
print ventures.sector2.value_counts()
# Out:
# Employment, training and education         23
# Physical health                            12
# Housing and local facilities                9
# Mental health and wellbeing                 7
# Environmental                               5
# Arts, heritage, sport and faith             4
# Conservation of the natural environment     2
# Income and financial inclusion              1
# Asset Management & Managed Workspace        1
# Family, friends and relationships           1
# dtype: int64
# ---
# Mental health and wellbeing                7
# Employment, training and education         7
# Family, friends and relationships          4
# Conservation of the natural environment    3
# Income and financial inclusion             2
# Physical health                            2
# Housing and local facilities               2
# Hosuing and local facilities               1
# Arts, heritage, sport and faith            1
# dtype: int64

# %%
ventures.groupby('incubator').invested.mean()
# Out:
# incubator
# bethnal      15000.000000
# hub                   NaN
# north         5116.666667
# wayra                 NaN
# Name: invested, dtype: float64

# %%
## LOAD ICRF DATA
##
headers = ['name','cash','postcode']
icrf = pandas.read_excel('data/ICRF Grants 31.01.14.xls',0,names=headers,skip_footer=1)
icrf.tail()
# Out:
#                                        name    cash  postcode
# 76                 Vine Trust Walsall (The)   97280   WS1 1RR
# 77                       Vital Regeneration   84780   NW8 8AB
# 78  West Itchen Community Trust Association   65100  SO14 0DJ
# 79                 Westminster drug project  140076  WC2B 6QX
# 80    Wirral Christian Centre Trust Limited   95760  CH41 2UE
#
# [5 rows x 3 columns]

# %%
icrf.cash.mean().round()
# Out:
# 96707.0

# %%
icrf.sum()
# Out:
# name        4ChildrenAccelerate CICAge UKAllied Health Pro...
# cash                                                  7833303
# postcode    E14 9NNNE46 3RUWC1H 9NAIP23 7BHN7 9APSW18 2SLM...
# dtype: object

# %%
## Data export
def icrf_dict(x):
    return {'name':x[1][0], 'amount':x[1][1], 'url':'#'}
data = {
    'icrf_mean':icrf.cash.mean().round(),
    'icrf_count':int(icrf.cash.count()),
    'icrf_items':[ icrf_dict(x) for x in icrf.iterrows() ],
}
with open('tmp.json','w') as f:
    import json
    json.dump(data,f)
data
# Out:
# {'icrf_count': 81,
#  'icrf_items': [{'amount': 73800, 'name': u'4Children', 'url': '#'},
#   {'amount': 72276, 'name': u'Accelerate CIC', 'url': '#'},
#   {'amount': 117626, 'name': u'Age UK', 'url': '#'},
#   {'amount': 132408,
#    'name': u'Allied Health Professionals Suffolk CIC',
#    'url': '#'},
#   {'amount': 126800, 'name': u'Best Beginnings', 'url': '#'},
#   {'amount': 117760, 'name': u'Beyond Autism', 'url': '#'},
#   {'amount': 105732, 'name': u'Big Life Group (The)', 'url': '#'},
#   {'amount': 59060,
#    'name': u'Bournemouth Churches Housing Association Limited',
#    'url': '#'},
#   {'amount': 66720,
#    'name': u'Bromley Healthcare Community Interest Company',
#    'url': '#'},
#   {'amount': 58303, 'name': u'Brook Advisory', 'url': '#'},
#   {'amount': 132768, 'name': u'Care Plus Group', 'url': '#'},
#   {'amount': 126200, 'name': u'Catch22 Charity Limited', 'url': '#'},
#   {'amount': 98850,
#    'name': u'Central Essex Community Services C.I.C.',
#    'url': '#'},
#   {'amount': 139525, 'name': u'Centre at Threeways (Halifax)', 'url': '#'},
#   {'amount': 71520, 'name': u"Children's Links", 'url': '#'},
#   {'amount': 95815,
#    'name': u'City And Hackney Association For Mental Health',
#    'url': '#'},
#   {'amount': 140972,
#    'name': u'Consortium of Voluntary Adoption Agencies UK Limited',
#    'url': '#'},
#   {'amount': 138600, 'name': u'Crime Reduction Initiatives (CRI)', 'url': '#'},
#   {'amount': 54000, 'name': u'Dartington Hall Trust (The)', 'url': '#'},
#   {'amount': 98353,
#    'name': u'Developing and Empowering Resources in Communities CIC',
#    'url': '#'},
#   {'amount': 89970,
#    'name': u'Disability Times Trust (t/a The Citizens Trust)',
#    'url': '#'},
#   {'amount': 138000,
#    'name': u'DISC - Co Durham VCS Working Together Forum',
#    'url': '#'},
#   {'amount': 145228, 'name': u'East Lancashire Moneyline Limited', 'url': '#'},
#   {'amount': 108650, 'name': u'Empower Community Management LLP', 'url': '#'},
#   {'amount': 95230,
#    'name': u'Essex Offender Services Community Interest Company',
#    'url': '#'},
#   {'amount': 50000,
#    'name': u'Ethical Property Company Limited (The)',
#    'url': '#'},
#   {'amount': 54045, 'name': u'Family Lives', 'url': '#'},
#   {'amount': 95836,
#    'name': u'Foresight North East Lincolnshire Ltd',
#    'url': '#'},
#   {'amount': 148600, 'name': u'Framework Housing Association', 'url': '#'},
#   {'amount': 104983, 'name': u'Furniture Resource Centre Ltd', 'url': '#'},
#   {'amount': 89000, 'name': u'Goodwin Development Trust', 'url': '#'},
#   {'amount': 129000, 'name': u'Greenwich Leisure Ltd', 'url': '#'},
#   {'amount': 73540, 'name': u'Health for Living Limited', 'url': '#'},
#   {'amount': 61600, 'name': u'Ideal For All', 'url': '#'},
#   {'amount': 99200, 'name': u'iPower Limited', 'url': '#'},
#   {'amount': 63796, 'name': u'Kennedy Scott Ltd', 'url': '#'},
#   {'amount': 109952, 'name': u'Khulisa', 'url': '#'},
#   {'amount': 74906, 'name': u'Lesbian and Gay Foundation (The)', 'url': '#'},
#   {'amount': 93740,
#    'name': u'London Early Years Foundation (The)',
#    'url': '#'},
#   {'amount': 79500, 'name': u'London Learning Consortium CIC', 'url': '#'},
#   {'amount': 65800, 'name': u'Lynton & Barnstaple Railway Trust', 'url': '#'},
#   {'amount': 71913, 'name': u'Medway Community Healthcare CIC', 'url': '#'},
#   {'amount': 99060, 'name': u'Mercia Community Action Ltd', 'url': '#'},
#   {'amount': 149300, 'name': u'Midlands Together CIC', 'url': '#'},
#   {'amount': 61718,
#    'name': u'Moseley Community Development Trust',
#    'url': '#'},
#   {'amount': 59400,
#    'name': u'Northern Construction Training & Regeneration CIC',
#    'url': '#'},
#   {'amount': 99950,
#    'name': u'Nuneaton and Bedworth Leisure Trust',
#    'url': '#'},
#   {'amount': 110125, 'name': u'Only Connect UK', 'url': '#'},
#   {'amount': 149280, 'name': u'People, Potential, Possibilities', 'url': '#'},
#   {'amount': 82400, 'name': u'Phoenix Social Enterprise Ltd', 'url': '#'},
#   {'amount': 74664, 'name': u'Plymouth Community Healthcare CIC', 'url': '#'},
#   {'amount': 87700,
#    'name': u'Prison Advice and Care Trust (pact)',
#    'url': '#'},
#   {'amount': 52250, 'name': u'Pure Innovations Group', 'url': '#'},
#   {'amount': 117325, 'name': u'Real Ideas Organisation CIC', 'url': '#'},
#   {'amount': 109110, 'name': u'Reds 10', 'url': '#'},
#   {'amount': 129000, 'name': u'RippleZ CIC', 'url': '#'},
#   {'amount': 76100, 'name': u'Roseland Community Wind Farm', 'url': '#'},
#   {'amount': 145296, 'name': u'Sandwell Community Caring Trust', 'url': '#'},
#   {'amount': 149846, 'name': u'Shared Lives Plus Limited', 'url': '#'},
#   {'amount': 65000, 'name': u'SLIC Training (International) Ltd', 'url': '#'},
#   {'amount': 70680, 'name': u'Social adVentures Limited', 'url': '#'},
#   {'amount': 98400,
#    'name': u'Southville Community Development Association',
#    'url': '#'},
#   {'amount': 68468, 'name': u'Spectrum Community Health CIC', 'url': '#'},
#   {'amount': 51233, 'name': u'St Antonys Centre', 'url': '#'},
#   {'amount': 149524, 'name': u"St Christopher's Fellowship", 'url': '#'},
#   {'amount': 90800, 'name': u'St Giles Trust', 'url': '#'},
#   {'amount': 91600, 'name': u'Steps to Work (Walsall)', 'url': '#'},
#   {'amount': 74836, 'name': u'StreetVibes Youth', 'url': '#'},
#   {'amount': 68508, 'name': u'Sutton Coldfield YMCA', 'url': '#'},
#   {'amount': 115895, 'name': u'Teens and Toddlers Ltd', 'url': '#'},
#   {'amount': 62630, 'name': u'Thames Reach', 'url': '#'},
#   {'amount': 106750, 'name': u'Thera Trust', 'url': '#'},
#   {'amount': 132534,
#    'name': u'TLG The Education Charity (formerly The Lighthouse Group UK LTD)',
#    'url': '#'},
#   {'amount': 71020, 'name': u'Trail-Blazers Mentoring Ltd', 'url': '#'},
#   {'amount': 103520, 'name': u'UK Youth', 'url': '#'},
#   {'amount': 106808, 'name': u'Validus Energy Ltd.', 'url': '#'},
#   {'amount': 97280, 'name': u'Vine Trust Walsall (The)', 'url': '#'},
#   {'amount': 84780, 'name': u'Vital Regeneration', 'url': '#'},
#   {'amount': 65100,
#    'name': u'West Itchen Community Trust Association',
#    'url': '#'},
#   {'amount': 140076, 'name': u'Westminster drug project', 'url': '#'},
#   {'amount': 95760,
#    'name': u'Wirral Christian Centre Trust Limited',
#    'url': '#'}],
#  'icrf_mean': 96707.0}

# %%
# DRAW A SANKEY DIAGRAM:
# Connecting:  target type  ->  product type  ->  purpose  -> sector
# --------
# Front-end data structure expectation:
# {"nodes":[  {"name":"Agricultural 'waste'"},... ],
#  "links":[  {"source":0,"target":1,"value":124.729,foundationSplit:[['Panahpur',9999]...]}, ..]}
# --------
# List of all unique values. Their index is their unique ID on the client.
sankey_nodes = pandas.concat([ 
                  df['target type'],
                  df['product type'],
                  df['purpose'],
                  df['sector'] 
              ]).unique()
sankey_get_index = {value:index for (index,value) in enumerate(sankey_nodes)}
# List of links to render. Indexes into sankey_nodes. foundationSplit = [ ['name',1234],['name2',5678] ]
def create_links(left,right):
    for (leftval,rightval),group in df.groupby([left,right]):
        subseries = group.groupby('foundation').invested.sum()
        # Each group is a link on the sankey chart
        yield {     'source':sankey_get_index[leftval],
                    'target':sankey_get_index[rightval],
                    'value' :group.invested.sum(),
                    'foundationSplit' : sorted(subseries.to_dict().items())
              }
sankey = {  
    'nodes': [{'name':x} for x in sankey_nodes], 
    'links': list(create_links('target type','product type'))\
             + list(create_links('product type','purpose'))\
             + list(create_links('purpose','sector'))
}

# %%
# Utility function used below...
def get_subframe(frame,year=None,foundation=None):
    if year is not None:
        frame = frame[ frame['date'].map(lambda x:x.year==year) ]
    if foundation is not None:
        frame = frame[ frame['foundation']==foundation ]
    return frame

# Ordered list of sectors is used across multiple charts
global_sectors = df.groupby(['sector']).invested.sum().order().index
global_sectors
# Out:
# Index([u'Healthy Living and Lifestyle', u'Personal and Social Well-Being', u'Climate Change & Conservation of the Natural Environment', u'Politics, Influence and Participation', u'Finance and Legal Matters', u'Education, Learning and Skills', u'Employment and Training', u'Multiple Sectors', u'Criminal Justice and Public Safety', u'Housing, Property and Essential Needs'], dtype='object')

# %%
# RENDER STACKED BAR CHART. Data structure for a chart:
# { legend: ['foo','bar'...],
#   series: [ {'major':2010, 'elements':[{'name':'foo','value':123...},...] },
#             {'major':2010, 'elements':[{'name':'foo','value':456...},...] }, ... ]
def pandas_barchart(frame):
    out = { 'legend' : list(global_sectors), 'series': [] }
    for year in [2010,2011,2012,2013]:
        tmp = get_subframe(frame,year=year)\
            .groupby(['sector'])\
            .invested.sum()\
            .reindex(index=global_sectors,fill_value=0)
        elements = [ {'name':x,'value':y} for (x,y) in tmp.iteritems() ]
        out['series'].append({'major':year, 'elements':elements})
    return out
barchart = {
    'all'                 : pandas_barchart(df),
    'foundation_panahpur' : pandas_barchart(get_subframe(df,foundation='Panahpur')),
    'foundation_lankelly' : pandas_barchart(get_subframe(df,foundation='The LankellyChase Foundation')),
    'foundation_barrow'   : pandas_barchart(get_subframe(df,foundation='The Barrow Cadbury Trust')),
}

# %%
# RENDER PIE CHART. Data structure for a chart:
# [{'name':'foo','value':123}, {'name'...} ...]
# -- pie1 draws the sector total values
def pandas_pie1(frame):
    tmp = frame.groupby(['sector'])\
        .invested.sum()\
        .reindex(index=global_sectors,fill_value=0)
    return [ {'name':x,'value':y} for (x,y) in tmp.iteritems() ]
pie1 = {
    'all'                 : pandas_pie1(df),
    'foundation_panahpur' : pandas_pie1(get_subframe(df,foundation='Panahpur')),
    'foundation_lankelly' : pandas_pie1(get_subframe(df,foundation='The LankellyChase Foundation')),
    'foundation_barrow'   : pandas_pie1(get_subframe(df,foundation='The Barrow Cadbury Trust')),
}

# %%
# RENDER ANOTHER PIE CHART. Data structure for a chart:
# [{'name':'foo','value':123}, {'name'...} ...]
# -- pie2 draws the secured vs unsecured product types
legend_pie2 = df.groupby(['product type']).invested.sum().order().index.tolist()
# Deliberately re-order the legend to give a better graph. Secured things go first.
for x in ['Loans and facilities - Partially secured','Loans and facilities - Unsecured']:
    legend_pie2.remove(x)
    legend_pie2.insert(0,x)
# --
def pandas_pie2(frame):
    tmp = frame.groupby(['product type'])\
        .invested.sum()\
        .reindex(index=legend_pie2,fill_value=0)
    return [ {'name':x,'value':y} for (x,y) in tmp.iteritems() ]
pie2 = {
    'all'                 : pandas_pie2(df),
    'foundation_panahpur' : pandas_pie2(get_subframe(df,foundation='Panahpur')),
    'foundation_lankelly' : pandas_pie2(get_subframe(df,foundation='The LankellyChase Foundation')),
    'foundation_barrow'   : pandas_pie2(get_subframe(df,foundation='The Barrow Cadbury Trust')),
}

# %%
# RENDER A SUNBURST. Data structure is recursive:
# { 'name':'root', 'children': [ 
#      { 'name':'foo', 'value':123 },
#      { 'name':'bar', 'value':456, 'children'=[...] }, ... ] }
# -- Group investments by coinvestment.
# Algorithm matches on the 'total investment' column.
sunburst = {'name':'Coinvestment','children':[]}
for (coinvestment),group in df.groupby(['coinvestment']):
    children = group.groupby('foundation').invested.sum()
    if len(children)==1 and children.sum()>=coinvestment:
        # Simple major segment
        (name,value) = children.to_dict().items()[0]
        if value!=coinvestment:
            print "WARNING: %s has investment of %d but coinvestment of %d" % (name,value,coinvestment)
        sunburst['children'].append({ 'name':name,'size':value })
    else:
        # Complex major segment with children
        entry = {'name':'Total Investment', 'size':coinvestment, 'children':[]}
        sunburst['children'].append(entry)
        for (name,value) in children.iteritems():
            entry['children'].append( {'name':name,'size':value} )
        entry['children'].append( {'name':'(others)', 'size':coinvestment - children.sum()} )
# Out:
# WARNING: Panahpur has investment of 10000 but coinvestment of 5000
# WARNING: Panahpur has investment of 30000 but coinvestment of 15000

# %%
investment_total = {
    'all'                 : df['invested'].sum(),
    'foundation_panahpur' : get_subframe(df,foundation='Panahpur')['invested'].sum(),
    'foundation_lankelly' : get_subframe(df,foundation='The LankellyChase Foundation')['invested'].sum(),
    'foundation_barrow'   : get_subframe(df,foundation='The Barrow Cadbury Trust')['invested'].sum(),
}
investment_total
# Out:
# {'all': 6229730.0,
#  'foundation_barrow': 1867320.0,
#  'foundation_lankelly': 2580000.0,
#  'foundation_panahpur': 1782410.0}

# %%
import json
# EXPORT: Write to file
graphs = {
          'bar' : barchart,
          'pie1' : pie1,
          'pie2' : pie2,
          'sankey' : sankey,
          'sunburst' : sunburst,
          'coinvestment_total' : df['coinvestment'].unique().sum(),
          'investment_total' : investment_total,
          }
with open('pandas_graphs.json','w') as f:
    json.dump(graphs,f)
